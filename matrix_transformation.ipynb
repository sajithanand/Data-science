# %%
#matrix transformation
#rotation

from matplotlib import pyplot as plt
# %matplotlib inline
from scipy import ndimage
import numpy as np
from PIL import Image


a=Image.open('image1.jpg')
b=np.array(a)
c=ndimage.rotate(b,120)
d=Image.fromarray(c)
d.save('image2.jpg')

plt.subplot(1,2,1)
plt.imshow(d)

m=Image.open('image3.jpeg')
n=np.array(m)
o=ndimage.rotate(n,130)
p=Image.fromarray(o)
plt.subplot(1,2,2)
plt.imshow(p)

# %%
#scaling

from matplotlib import pyplot as plt
# %matplotlib inline
from scipy import ndimage
import numpy as np
from PIL import Image


a=Image.open('image1.jpg')
b=np.array(a)
c=ndimage.zoom(b,(25,40,1))
d=Image.fromarray(c)
plt.imshow(d)

# %%
#shearing
from matplotlib import pyplot as plt
# %matplotlib inline
from scipy import ndimage
import numpy as np
from PIL import Image


a=Image.open('image1.jpg')
b=np.array(a)
height, width, colors = array.shape
d=np.array([[1,0,0,0,1,0,0,0,1]])
e=nd.image.affine_transform
